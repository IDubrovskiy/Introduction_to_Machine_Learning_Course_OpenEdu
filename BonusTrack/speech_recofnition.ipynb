# %%
# !pip install -q SpeechRecognition==3.8.1
# !pip install -q pocketsphinx==5.0.0
# Out:
#      в”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓ 32.8/32.8 MB 20.3 MB/s eta 0:00:00
#      в”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓв”Ѓ 29.1/29.1 MB 31.6 MB/s eta 0:00:00

# %%
import speech_recognition as sr

# %%
# РРјСЏ С„Р°Р№Р»Р°, РєРѕС‚РѕСЂС‹Р№ С‚СЂРµР±СѓРµС‚СЃСЏ СЂР°СЃРїРѕР·РЅР°С‚СЊ
AUDIO_FILE = '7.wav'

# Р§С‚РµРЅРёРµ С„Р°Р№Р»Р°
r = sr.Recognizer()
with sr.AudioFile(AUDIO_FILE) as source:
    audio = r.record(source)

# Р Р°СЃРїРѕР·РЅР°РІР°РЅРёРµ СЃ РїРѕРјРѕС‰СЊСЋ Sphinx
try:
    print("Р РµР·СѓР»СЊС‚Р°С‚ Sphinx: " + r.recognize_sphinx(audio))
except sr.UnknownValueError:
    print("РћС€РёР±РєР°: Sphinx could not understand audio")
except sr.RequestError as e:
    print("РћС€РёР±РєР°: Sphinx error; {0}".format(e))
# Out:
# Р РµР·СѓР»СЊС‚Р°С‚ Sphinx: go home to chickens before they had show

# %%
import pandas as pd

# %%
db = pd.read_csv("Data.csv")
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_6844\4069429989.py:1: DtypeWarning: Columns (8,15,16,17,18,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   db = pd.read_csv("Data.csv")

# %%
db[db.sinpkt == '???.34']
# Out:
#             dur proto   service state  spkts  dpkts  sbytes  dbytes  \
# 2342   0.157418   tcp      http   FIN     16      6   10578     268
# 23429  0.046538   tcp         -   FIN      6      8     320    1946
# 28864  0.018822   tcp         -   FIN     16     18    1540    1644
# 29323  0.018667   tcp         -   FIN     16     18    1540    1644
# 30683   0.01822   tcp         -   FIN     16     18    1540    1644
# 31999  0.264931   tcp         -   FIN     26     26    4088    2872
# 32854  0.018974   tcp         -   FIN     16     18    1540    1644
# 33463  0.036221   tcp         -   FIN     16     18    1540    1644
# 33673  0.019419   tcp         -   FIN     16     18    1540    1644
# 37205  0.047134   tcp  ftp-data   FIN      6      8     320    1890
# 38167  0.022272   tcp         -   FIN     16     18    1540    1644
#
#               rate  sttl  ...  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 2342    133.402789   254  ...                 1                 1
# ...

# %%
db = db.drop(index=[1386, 36799, 71259])

# %%
db = db.drop(index=[2111, 44001, 44003])

# %%
db.to_csv("Data.csv", index=False)
