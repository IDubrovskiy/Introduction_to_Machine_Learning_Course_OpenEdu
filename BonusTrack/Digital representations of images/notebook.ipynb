# %%
import cv2
print('OpenCV version:', cv2.__version__)
# Out:
# OpenCV version: 4.4.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
path = 'img/'
file_name = 'danist-gIrvhDFuDn0-unsplash.jpg'

# %% [markdown]
# Read the image using cv2.imread() command

# %%
img = cv2.imread(path + file_name)

# %% [markdown]
# img object is an array of the ndarray type, allowing to perform various operations with it and, correspondingly, the image. Let's consider its structure

# %%
print(type(img))
print(img.shape)
print(img.shape[1] / img.shape[0])
# Out:
# <class 'numpy.ndarray'>
# (1080, 1920, 3)
# 1.7777777777777777

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()

# %%
h, w, c = RGB_img.shape
new_width = 890

k = float(w) / h
dim = (new_width, int(new_width / k))

resized_RGB_img = cv2.resize(RGB_img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized_RGB_img)
plt.show()

# %%
print(resized_RGB_img.shape)
# Out:
# (500, 890, 3)

# %%
path = ''
file_name = 'resized.jpg'

cv2.imwrite(path + file_name, cv2.cvtColor(resized_RGB_img, cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
red_intense_img = resized_RGB_img.copy()

red_intense_img[:, :, 0] = np.around(np.clip(red_intense_img[:, :, 0] * 1.26, 0, 255))

plt.imshow(red_intense_img)
plt.show()

# %%
R, G, B = red_intense_img[278][483]
print('Red channel:', R)
print('Green channel: ', G)
print('Blue channel:  ', B)
# Out:
# Red channel: 255
# Green channel:  150
# Blue channel:   107
